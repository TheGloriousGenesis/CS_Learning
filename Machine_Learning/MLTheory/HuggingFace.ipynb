# %%
from huggingface_hub import HfApi, ModelFilter

# %%
api = HfApi()
models = api.list_models(
    filter=ModelFilter(
		task="image-classification",
		library="pytorch",
		trained_dataset="imagenet"
	)
)

# %%
models.
# Out:
# /Users/anasthasia_manu/Desktop/practice_ml/ml_course/envs/lib/python3.9/site-packages/huggingface_hub/utils/_deprecation.py:229: FutureWarning: 'list_models' currently returns a list of objects but is planned to be a generator starting from version 0.14 in order to implement pagination. Please avoid to use `list_models(...).__len__` or explicitly convert the output to a list first with `list(iter(list_models)(...))`.
#   warnings.warn(self._deprecation_msg.format(attr_name=attr_name), FutureWarning)
# [ModelInfo: {
#    {'_id': '621ffdc136468d709f177b93',
#     'author': 'WinKawaks',
#     'config': None,
#     'downloads': 12468,
#     'id': 'WinKawaks/vit-small-patch16-224',
#     'lastModified': '2023-03-18T22:00:21.000Z',
#     'library_name': 'transformers',
#     'likes': 2,
#     'modelId': 'WinKawaks/vit-small-patch16-224',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '592871fe95484877e8a4b4acc8f16755ec29a770',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'model.safetensors', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'safetensors', 'vit', 'image-classification', 'dataset:imagenet', 'transformers', 'vision',
#              'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f177b94',
#     'author': 'WinKawaks',
#     'config': None,
#     'downloads': 433,
#     'id': 'WinKawaks/vit-tiny-patch16-224',
#     'lastModified': '2022-01-30T18:04:38.000Z',
#     'library_name': 'transformers',
#     'likes': 4,
#     'modelId': 'WinKawaks/vit-tiny-patch16-224',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'fd78e4f96a9936843a178feae1ed30453b59b44d',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'vit', 'image-classification', 'dataset:imagenet', 'transformers', 'vision', 'license:apache-2.0',
#              'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17a5d9',
#     'author': 'deepmind',
#     'config': None,
#     'downloads': 547,
#     'id': 'deepmind/vision-perceiver-conv',
#     'lastModified': '2021-12-11T13:12:42.000Z',
#     'library_name': 'transformers',
#     'likes': 4,
#     'modelId': 'deepmind/vision-perceiver-conv',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '795b5eea5867940bd8fa46105029874afce6f037',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'perceiver', 'image-classification', 'dataset:imagenet', 'arxiv:2107.14795', 'transformers',
#              'license:apache-2.0', 'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17a5da',
#     'author': 'deepmind',
#     'config': None,
#     'downloads': 578,
#     'id': 'deepmind/vision-perceiver-fourier',
#     'lastModified': '2021-12-11T13:13:25.000Z',
#     'library_name': 'transformers',
#     'likes': 1,
#     'modelId': 'deepmind/vision-perceiver-fourier',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '6900e2e595f397e6d7955db5234e13f2ad6ed67b',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'perceiver', 'image-classification', 'dataset:imagenet', 'arxiv:2107.14795', 'transformers',
#              'license:apache-2.0', 'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17a5db',
#     'author': 'deepmind',
#     'config': None,
#     'downloads': 453,
#     'id': 'deepmind/vision-perceiver-learned',
#     'lastModified': '2021-12-13T09:25:29.000Z',
#     'library_name': 'transformers',
#     'likes': 8,
#     'modelId': 'deepmind/vision-perceiver-learned',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'e3d8bac358a9994ce2f0887fad97855ab6e14691',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'perceiver', 'image-classification', 'dataset:imagenet', 'arxiv:2107.14795', 'transformers',
#              'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17add5',
#     'author': 'facebook',
#     'config': None,
#     'downloads': 6837,
#     'id': 'facebook/deit-base-distilled-patch16-224',
#     'lastModified': '2022-07-13T11:39:38.000Z',
#     'library_name': 'transformers',
#     'likes': 15,
#     'modelId': 'facebook/deit-base-distilled-patch16-224',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'a0fc9b37fdb63c112e76104f669208784ecfe4ea',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'deit', 'image-classification', 'dataset:imagenet', 'arxiv:2012.12877', 'arxiv:2006.03677',
#              'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17add6',
#     'author': 'facebook',
#     'config': None,
#     'downloads': 574,
#     'id': 'facebook/deit-base-distilled-patch16-384',
#     'lastModified': '2022-07-13T11:40:20.000Z',
#     'library_name': 'transformers',
#     'likes': 1,
#     'modelId': 'facebook/deit-base-distilled-patch16-384',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'd5642c165024ea0619ad72ab3e26d867eabdcdab',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'deit', 'image-classification', 'dataset:imagenet', 'arxiv:2012.12877', 'arxiv:2006.03677',
#              'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17add9',
#     'author': 'facebook',
#     'config': None,
#     'downloads': 7630,
#     'id': 'facebook/deit-small-distilled-patch16-224',
#     'lastModified': '2022-07-13T11:41:21.000Z',
#     'library_name': 'transformers',
#     'likes': 3,
#     'modelId': 'facebook/deit-small-distilled-patch16-224',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '3559f915da8724f0eba2252acb20cc96649c6289',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'deit', 'image-classification', 'dataset:imagenet', 'arxiv:2012.12877', 'arxiv:2006.03677',
#              'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17addb',
#     'author': 'facebook',
#     'config': None,
#     'downloads': 375,
#     'id': 'facebook/deit-tiny-distilled-patch16-224',
#     'lastModified': '2022-07-13T11:41:55.000Z',
#     'library_name': 'transformers',
#     'likes': 2,
#     'modelId': 'facebook/deit-tiny-distilled-patch16-224',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '488ad407f8f6bcfc79829ece3507658c46d15563',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'deit', 'image-classification', 'dataset:imagenet', 'arxiv:2012.12877', 'arxiv:2006.03677',
#              'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17addc',
#     'author': 'facebook',
#     'config': None,
#     'downloads': 1303,
#     'id': 'facebook/deit-tiny-patch16-224',
#     'lastModified': '2022-07-13T11:53:31.000Z',
#     'library_name': 'transformers',
#     'likes': 1,
#     'modelId': 'facebook/deit-tiny-patch16-224',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'b3428f18dcc7b543470d07f14b4a4157815d1880',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'vit', 'image-classification', 'dataset:imagenet', 'arxiv:2012.12877', 'arxiv:2006.03677',
#              'transformers', 'license:apache-2.0', 'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b571',
#     'author': 'glasses',
#     'config': None,
#     'downloads': 1,
#     'id': 'glasses/eca_resnet26t',
#     'lastModified': '2021-11-30T20:21:22.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'glasses/eca_resnet26t',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '733959db40c94fde4f26c6c63bfdf8ed01454e8e',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1512.03385', 'arxiv:1812.01187', 'transformers',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b58e',
#     'author': 'glasses',
#     'config': None,
#     'downloads': 2,
#     'id': 'glasses/resnet152',
#     'lastModified': '2021-11-30T20:12:19.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'glasses/resnet152',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '2472cf9411a6fc59b80689b3f8df13614ffdd0ab',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1512.03385', 'arxiv:1812.01187', 'transformers',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b590',
#     'author': 'glasses',
#     'config': None,
#     'downloads': 13,
#     'id': 'glasses/resnet18',
#     'lastModified': '2021-11-30T20:06:28.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'glasses/resnet18',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'a15b2ef76c4e01cc6b3f4518f56c1c98722d6793',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.org.chromium.Chromium.DyPFg4', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.org.chromium.Chromium.J5ns2q/SingletonCookie', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.org.chromium.Chromium.oNKDLG/SingletonCookie', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {
#      {'blob_id': None,
#       'lfs': None,
#       'rfilename': 'VSFeedbackVSRTCLogs/20210409_083938_16179575780260_VSCode.log',
#       'size': None}
#    },
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'VSFeedbackVSRTCLogs/20210409_083938_Agent.log', 'size': None},
#                  RepoFile: {
#      {'blob_id': None,
#       'lfs': None,
#       'rfilename': 'VSFeedbackVSRTCLogs/20210409_103612_16179645728160_VSCode.log',
#       'size': None}
#    },
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'VSFeedbackVSRTCLogs/20210409_103613_Agent.log', 'size': None},
#                  RepoFile: {
#      {'blob_id': None,
#       'lfs': None,
#       'rfilename': 'VSFeedbackVSRTCLogs/20210409_110958_16179665980940_VSCode.log',
#       'size': None}
#    },
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config-err-Edzi90', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {
#      {'blob_id': None,
#       'lfs': None,
#       'rfilename': 'remote-file-71752ccfe2464e99/1d68001ef112fa197e0de1f2cbc5ab57ebf464a5ae676667c4e51b82762627a7/0178b70fdabe-0x8D8F230C59F9D48',
#       'size': None}
#    },
#                  RepoFile: {
#      {'blob_id': None,
#       'lfs': None,
#       'rfilename': 'remote-file-71752ccfe2464e99/1d68001ef112fa197e0de1f2cbc5ab57ebf464a5ae676667c4e51b82762627a7/0178b77db7fd-0x8D8F230C59F9D48',
#       'size': None}
#    },
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'resnet18/config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'resnet18/pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'vscode-ipc', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1512.03385', 'arxiv:1812.01187', 'transformers',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b593',
#     'author': 'glasses',
#     'config': None,
#     'downloads': 4,
#     'id': 'glasses/resnet26',
#     'lastModified': '2021-11-30T20:06:59.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'glasses/resnet26',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '38114d9e6730ef324ba8fcc109031d706769cf97',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1512.03385', 'arxiv:1812.01187', 'transformers',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b595',
#     'author': 'glasses',
#     'config': None,
#     'downloads': 3,
#     'id': 'glasses/resnet26d',
#     'lastModified': '2021-11-30T20:07:33.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'glasses/resnet26d',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '4256019677b10c45bdb178090012fe7a4287042a',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1512.03385', 'arxiv:1812.01187', 'transformers',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b597',
#     'author': 'glasses',
#     'config': None,
#     'downloads': 1,
#     'id': 'glasses/resnet34',
#     'lastModified': '2021-11-30T20:08:12.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'glasses/resnet34',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'ee62b58fa882d4a4fd6d40b4c06fcb99c7599cf5',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1512.03385', 'arxiv:1812.01187', 'transformers',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b599',
#     'author': 'glasses',
#     'config': None,
#     'downloads': 3,
#     'id': 'glasses/resnet34d',
#     'lastModified': '2021-11-30T20:08:51.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'glasses/resnet34d',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'b53c002f7bd81002fac17b1775e726fe6f3f6073',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1512.03385', 'arxiv:1812.01187', 'transformers',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b59b',
#     'author': 'glasses',
#     'config': None,
#     'downloads': 3,
#     'id': 'glasses/resnet50',
#     'lastModified': '2021-11-30T20:09:35.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'glasses/resnet50',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '761c66bf309109ad629044fa4d731e6b9de5f290',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1512.03385', 'arxiv:1812.01187', 'transformers',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b59d',
#     'author': 'glasses',
#     'config': None,
#     'downloads': 4,
#     'id': 'glasses/resnet50d',
#     'lastModified': '2021-11-30T20:10:20.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'glasses/resnet50d',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '2acf4629bbe1f8e06444b0bb22a4afc70384dc62',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1512.03385', 'arxiv:1812.01187', 'transformers',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b7d8',
#     'author': 'google',
#     'config': None,
#     'downloads': 5292,
#     'id': 'google/vit-base-patch16-384',
#     'lastModified': '2022-01-12T08:05:44.000Z',
#     'library_name': 'transformers',
#     'likes': 9,
#     'modelId': 'google/vit-base-patch16-384',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'be89a4abf1f427fe502d37f261b8b6d6da7894bc',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'jax', 'vit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2010.11929', 'arxiv:2006.03677', 'transformers', 'vision', 'license:apache-2.0',
#              'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b7de',
#     'author': 'google',
#     'config': None,
#     'downloads': 565,
#     'id': 'google/vit-large-patch16-384',
#     'lastModified': '2022-01-28T10:22:26.000Z',
#     'library_name': 'transformers',
#     'likes': 5,
#     'modelId': 'google/vit-large-patch16-384',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '4b143e77059a54c70b348a76677ab9946f584e13',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'jax', 'vit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2010.11929', 'arxiv:2006.03677', 'transformers', 'vision', 'license:apache-2.0',
#              'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17b7e0',
#     'author': 'google',
#     'config': None,
#     'downloads': 23230,
#     'id': 'google/vit-large-patch32-384',
#     'lastModified': '2022-01-28T10:24:24.000Z',
#     'library_name': 'transformers',
#     'likes': 4,
#     'modelId': 'google/vit-large-patch32-384',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'a2b30ad36d02e99f045cd2ecfc71e0ae16991efa',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'jax', 'vit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2010.11929', 'arxiv:2006.03677', 'transformers', 'vision', 'license:apache-2.0',
#              'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17ced7',
#     'author': 'julien-c',
#     'config': None,
#     'downloads': 75,
#     'id': 'julien-c/timm-dpn92',
#     'lastModified': '2021-02-18T11:18:56.000Z',
#     'library_name': 'timm',
#     'likes': 0,
#     'modelId': 'julien-c/timm-dpn92',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '5411e038a5952ec38968e55c6c9b7762a45d0110',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1707.01629', 'arxiv:1906.02659', 'arxiv:2010.15052', 'timm',
#              'image-classification', 'dpn', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17d6a0',
#     'author': 'leftthomas',
#     'config': None,
#     'downloads': 3,
#     'id': 'leftthomas/resnet50',
#     'lastModified': '2022-03-11T12:53:14.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'leftthomas/resnet50',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '19128d842d5b7589cbf02b5002d70f9c65586796',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'configuration_resnet.py', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'modeling_resnet.py', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'resnet', 'dataset:imagenet', 'arxiv:1512.03385', 'transformers', 'image-classification',
#              'license:afl-3.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17dece',
#     'author': 'microsoft',
#     'config': None,
#     'downloads': 164787,
#     'id': 'microsoft/beit-base-patch16-224-pt22k-ft22k',
#     'lastModified': '2023-02-27T15:08:16.000Z',
#     'library_name': 'transformers',
#     'likes': 37,
#     'modelId': 'microsoft/beit-base-patch16-224-pt22k-ft22k',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '9da301148150e37e533abef672062fa49f6bda4f',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'jax', 'beit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2106.08254', 'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17decf',
#     'author': 'microsoft',
#     'config': None,
#     'downloads': 4490,
#     'id': 'microsoft/beit-base-patch16-224-pt22k',
#     'lastModified': '2022-01-28T10:18:13.000Z',
#     'library_name': 'transformers',
#     'likes': 1,
#     'modelId': 'microsoft/beit-base-patch16-224-pt22k',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '9aabc608cc017577cb8fb58968e66e0d8f581da1',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'jax', 'beit', 'dataset:imagenet', 'dataset:imagenet-21k', 'arxiv:2106.08254', 'transformers',
#              'image-classification', 'vision', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17ded0',
#     'author': 'microsoft',
#     'config': None,
#     'downloads': 22628,
#     'id': 'microsoft/beit-base-patch16-224',
#     'lastModified': '2023-02-27T17:56:38.000Z',
#     'library_name': 'transformers',
#     'likes': 3,
#     'modelId': 'microsoft/beit-base-patch16-224',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '5f0307aec45cf4c914ee8700108b779fb8390654',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'jax', 'beit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2106.08254', 'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17ded1',
#     'author': 'microsoft',
#     'config': None,
#     'downloads': 145,
#     'id': 'microsoft/beit-base-patch16-384',
#     'lastModified': '2022-01-28T10:19:30.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'microsoft/beit-base-patch16-384',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '3f8133fb4ce0cd802b8eab61edd881bc2a624597',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'jax', 'beit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2106.08254', 'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17ded3',
#     'author': 'microsoft',
#     'config': None,
#     'downloads': 27131,
#     'id': 'microsoft/beit-large-patch16-224-pt22k-ft22k',
#     'lastModified': '2023-02-27T17:56:06.000Z',
#     'library_name': 'transformers',
#     'likes': 3,
#     'modelId': 'microsoft/beit-large-patch16-224-pt22k-ft22k',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'c62906117bde428208791a2bc6e8a7e6c15413b8',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'jax', 'beit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2106.08254', 'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17ded4',
#     'author': 'microsoft',
#     'config': None,
#     'downloads': 1656,
#     'id': 'microsoft/beit-large-patch16-224-pt22k',
#     'lastModified': '2022-01-28T10:20:43.000Z',
#     'library_name': 'transformers',
#     'likes': 1,
#     'modelId': 'microsoft/beit-large-patch16-224-pt22k',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'd1b5d428118fa9b220cc1585289fb5a6bc5ceb92',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'jax', 'beit', 'dataset:imagenet', 'dataset:imagenet-21k', 'arxiv:2106.08254', 'transformers',
#              'image-classification', 'vision', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17ded5',
#     'author': 'microsoft',
#     'config': None,
#     'downloads': 140,
#     'id': 'microsoft/beit-large-patch16-224',
#     'lastModified': '2022-01-28T10:19:16.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'microsoft/beit-large-patch16-224',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '0bd443cfdfa82333978cac2253da417b33ff5018',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'jax', 'beit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2106.08254', 'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17ded6',
#     'author': 'microsoft',
#     'config': None,
#     'downloads': 22,
#     'id': 'microsoft/beit-large-patch16-384',
#     'lastModified': '2022-01-28T10:19:50.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'microsoft/beit-large-patch16-384',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '6ad3dc484125f460f2ce85ea2296732db291bdf1',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'jax', 'beit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2106.08254', 'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17ded7',
#     'author': 'microsoft',
#     'config': None,
#     'downloads': 206,
#     'id': 'microsoft/beit-large-patch16-512',
#     'lastModified': '2022-01-28T10:20:07.000Z',
#     'library_name': 'transformers',
#     'likes': 2,
#     'modelId': 'microsoft/beit-large-patch16-512',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'f03bc4a94ad012c74bdd32d80ec7169a751034f9',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'jax', 'beit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2106.08254', 'transformers', 'vision', 'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17e51a',
#     'author': 'nateraw',
#     'config': None,
#     'downloads': 2,
#     'id': 'nateraw/resnet50',
#     'lastModified': '2021-04-15T23:19:34.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'nateraw/resnet50',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '74b8ab5d279c8073d535c0a98b64f9089ff59780',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'resnet', 'dataset:imagenet', 'transformers', 'image-classification']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17e6f2',
#     'author': 'nielsr',
#     'config': None,
#     'downloads': 1,
#     'id': 'nielsr/beit-base-patch16-224',
#     'lastModified': '2021-09-13T13:36:43.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'nielsr/beit-base-patch16-224',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '7ad81663e30d294727629c136ace319a8b875fa6',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'flax_model.msgpack', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'jax', 'beit', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'arxiv:2106.08254', 'transformers', 'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f17e6f3',
#     'author': 'nielsr',
#     'config': None,
#     'downloads': 0,
#     'id': 'nielsr/beit-large-patch16-224-pt22k-ft22k',
#     'lastModified': '2021-08-03T15:49:41.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'nielsr/beit-large-patch16-224-pt22k-ft22k',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '6ae4dfaec1a310c4d0d69b1accf747854b1f9632',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'beit', 'dataset:imagenet', 'dataset:imagenet-21k', 'arxiv:2106.08254', 'transformers',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f180003',
#     'author': 'sail',
#     'config': None,
#     'downloads': 8,
#     'id': 'sail/poolformer_m36',
#     'lastModified': '2022-04-08T07:49:03.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'sail/poolformer_m36',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'd8dbe79affcac9d5bbe80c702d327c8af09523ec',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'poolformer', 'image-classification', 'dataset:imagenet', 'arxiv:2111.11418', 'transformers',
#              'vision', 'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f180004',
#     'author': 'sail',
#     'config': None,
#     'downloads': 56,
#     'id': 'sail/poolformer_m48',
#     'lastModified': '2022-04-08T07:48:25.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'sail/poolformer_m48',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '752b4a4de30d3fb40c59db413fa6f9ce51be2cc0',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'poolformer', 'image-classification', 'dataset:imagenet', 'arxiv:2111.11418', 'transformers',
#              'vision', 'license:apache-2.0', 'autotrain_compatible', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f180005',
#     'author': 'sail',
#     'config': None,
#     'downloads': 998,
#     'id': 'sail/poolformer_s12',
#     'lastModified': '2022-04-08T07:48:14.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'sail/poolformer_s12',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '81dd35aba1f435d6ade0f31c0c99f02097efedf8',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'poolformer', 'image-classification', 'dataset:imagenet', 'arxiv:2111.11418', 'transformers',
#              'vision', 'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f180006',
#     'author': 'sail',
#     'config': None,
#     'downloads': 3,
#     'id': 'sail/poolformer_s24',
#     'lastModified': '2022-04-08T07:48:50.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'sail/poolformer_s24',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'ff108f65a6511d2bacead81d14792d4a954b1999',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'poolformer', 'image-classification', 'dataset:imagenet', 'arxiv:2111.11418', 'transformers',
#              'vision', 'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f180007',
#     'author': 'sail',
#     'config': None,
#     'downloads': 6,
#     'id': 'sail/poolformer_s36',
#     'lastModified': '2022-04-08T07:48:39.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'sail/poolformer_s36',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '1d740b215d07f480fa51efa16df83a63d5f6acf2',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'poolformer', 'image-classification', 'dataset:imagenet', 'arxiv:2111.11418', 'transformers',
#              'vision', 'license:apache-2.0', 'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f1803bd',
#     'author': 'sgugger',
#     'config': None,
#     'downloads': 122,
#     'id': 'sgugger/resnet50d',
#     'lastModified': '2021-11-03T16:22:16.000Z',
#     'library_name': 'timm',
#     'likes': 3,
#     'modelId': 'sgugger/resnet50d',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '4b32487424f0f5f2f17ffb60d578b8e5ac7ddc35',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:1512.03385', 'arxiv:1812.01187', 'arxiv:1906.02659',
#              'arxiv:2010.15052', 'timm', 'image-classification', 'resnet', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '621ffdc136468d709f180f29',
#     'author': 'timm',
#     'config': None,
#     'downloads': 1349,
#     'id': 'timm/eca_nfnet_l0',
#     'lastModified': '2021-09-07T18:35:59.000Z',
#     'library_name': 'timm',
#     'likes': 1,
#     'modelId': 'timm/eca_nfnet_l0',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'd1c0fff069f8cb8d83c1f42767cc4fcc8b21a3f3',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'dataset:imagenet', 'arxiv:2102.06171', 'arxiv:1910.03151', 'arxiv:1903.10520',
#              'arxiv:1906.02659', 'arxiv:2010.15052', 'arxiv:1909.13719', 'timm', 'image-classification',
#              'normalization-free', 'efficient-channel-attention', 'license:apache-2.0', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '6257d66ccf42812891aabd29',
#     'author': 'facebook',
#     'config': None,
#     'downloads': 1932,
#     'id': 'facebook/data2vec-vision-base',
#     'lastModified': '2022-05-03T15:52:10.000Z',
#     'library_name': 'transformers',
#     'likes': 2,
#     'modelId': 'facebook/data2vec-vision-base',
#     'pipeline_tag': 'feature-extraction',
#     'private': False,
#     'securityStatus': None,
#     'sha': '72a7bdadab41d0e9a2c8d6887b9f8a50eebb8e0f',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'data2vec-vision', 'feature-extraction', 'dataset:imagenet', 'dataset:imagenet-1k',
#              'arxiv:2202.03555', 'arxiv:2106.08254', 'transformers', 'image-classification', 'vision',
#              'license:apache-2.0', 'has_space']}
#  },
#  ModelInfo: {
#    {'_id': '6257d677dd5b3179044d9ebf',
#     'author': 'facebook',
#     'config': None,
#     'downloads': 156,
#     'id': 'facebook/data2vec-vision-large',
#     'lastModified': '2023-03-21T10:50:04.000Z',
#     'library_name': 'transformers',
#     'likes': 1,
#     'modelId': 'facebook/data2vec-vision-large',
#     'pipeline_tag': 'feature-extraction',
#     'private': False,
#     'securityStatus': None,
#     'sha': '983e5280c61484f20f28fb08d9eafc7ff709ecef',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'model.safetensors', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'safetensors', 'data2vec-vision', 'feature-extraction', 'dataset:imagenet',
#              'dataset:imagenet-1k', 'arxiv:2202.03555', 'arxiv:2106.08254', 'transformers', 'image-classification',
#              'vision', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '6257d6a0cf42812891aabe53',
#     'author': 'facebook',
#     'config': None,
#     'downloads': 4,
#     'id': 'facebook/data2vec-vision-large-ft1k',
#     'lastModified': '2022-05-03T15:22:49.000Z',
#     'library_name': 'transformers',
#     'likes': 3,
#     'modelId': 'facebook/data2vec-vision-large-ft1k',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '9933efaca13b79863d36579c9a339c84cb0e9eca',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'data2vec-vision', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-1k',
#              'arxiv:2202.03555', 'arxiv:2106.08254', 'transformers', 'vision', 'license:apache-2.0',
#              'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '6257d6b1dcc738ea491a9efb',
#     'author': 'facebook',
#     'config': None,
#     'downloads': 324,
#     'id': 'facebook/data2vec-vision-base-ft1k',
#     'lastModified': '2022-05-03T15:08:31.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'facebook/data2vec-vision-base-ft1k',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '9c7678bab4dcde1342510d62f201db7f8e98e6ff',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'preprocessor_config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'tf_model.h5', 'size': None}],
#     'tags': ['pytorch', 'tf', 'data2vec-vision', 'image-classification', 'dataset:imagenet', 'dataset:imagenet-1k',
#              'arxiv:2202.03555', 'arxiv:2106.08254', 'transformers', 'vision', 'license:apache-2.0',
#              'autotrain_compatible']}
#  },
#  ModelInfo: {
#    {'_id': '62ab5a16e3cc78f1b174cef9',
#     'author': 'chlab',
#     'config': None,
#     'downloads': 0,
#     'id': 'chlab/efficientnet_61_planet_detection',
#     'lastModified': '2022-06-17T17:12:07.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'chlab/efficientnet_61_planet_detection',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': 'a29a99abd85bcc28a3d9525632648803b980c4e1',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'efficientnet_61_planet_detection', 'Python 3.7+', 'dataset:imagenet', 'dataset:imagenet-21k',
#              'transformers', 'vision', 'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '62ab8f4fccde9e9d1034647b',
#     'author': 'chlab',
#     'config': None,
#     'downloads': 0,
#     'id': 'chlab/efficientnet_47_planet_detection',
#     'lastModified': '2022-06-17T14:24:09.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'chlab/efficientnet_47_planet_detection',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '011d96ca1c1718a3c234fda2826f8147ccb8bb4f',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'Python 3.7+', 'dataset:imagenet', 'dataset:imagenet-21k', 'transformers', 'vision',
#              'image-classification', 'license:apache-2.0']}
#  },
#  ModelInfo: {
#    {'_id': '62ab9090ccde9e9d1035ec82',
#     'author': 'chlab',
#     'config': None,
#     'downloads': 1,
#     'id': 'chlab/efficientnet_75_planet_detection',
#     'lastModified': '2022-06-17T14:23:52.000Z',
#     'library_name': 'transformers',
#     'likes': 0,
#     'modelId': 'chlab/efficientnet_75_planet_detection',
#     'pipeline_tag': 'image-classification',
#     'private': False,
#     'securityStatus': None,
#     'sha': '08a757a3100fb0b805916c245697a802b2fbe9aa',
#     'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'README.md', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'config.json', 'size': None},
#                  RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'pytorch_model.bin', 'size': None}],
#     'tags': ['pytorch', 'Python 3.7+', 'dataset:imagenet', 'dataset:imagenet-21k', 'transformers', 'vision',
#              'image-classification', 'license:apache-2.0']}
#  }]
